# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Dataset/Salary.csv')
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# 32             12.3  128765
# 33             12.9  135675
# 34             13.5  139465

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
y=df['Salary']
x=df.drop(['Salary'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.25)

# %%
x_test
# Out:
#     YearsExperience
# 26              9.5
# 13              4.1
# 24              8.7
# 21              7.1
# 15              4.9
# 29             10.5
# 19              6.0
# 12              4.0
# 8               3.2

# %%
y_test
# Out:
# 26    116969
# 13     57081
# 24    109431
# 21     98273
# 15     67938
# 29    121872
# 19     93940
# 12     56957
# 8      64445
# Name: Salary, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 8)
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=8)

# %%
pre=classifier.predict(x_test)

# %%
pre
# Out:
# array([ 91738,  54445,  81363,  66029,  54445, 105582,  55794,  54445,
#         39891])

# %%
print(y_test)
# Out:
# 26    116969
# 13     57081
# 24    109431
# 21     98273
# 15     67938
# 29    121872
# 19     93940
# 12     56957
# 8      64445
# Name: Salary, dtype: int64

# %%
type(x_test)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.metrics import mean_squared_error
print('MSC is :',mean_squared_error(y_test,pre))
# Out:
# MSC is : 37934232.333333336

# %%
x=int(input('enter your experience'))
d=pd.Series(x)
d1=pd.DataFrame(d)
pre=classifier.predict(d1)
print('your salary prediction is :',pre)
# Out:
# enter your experience4
# your salary prediction is : [54445]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
