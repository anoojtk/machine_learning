# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/Dataset/homeprices (1).csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
df.describe()
# Out:
#               area          price
# count     5.000000       5.000000
# mean   3280.000000  626000.000000
# std     540.370243   74949.983322
# min    2600.000000  550000.000000
# 25%    3000.000000  565000.000000
# 50%    3200.000000  610000.000000
# 75%    3600.000000  680000.000000
# max    4000.000000  725000.000000

# %%
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
df.columns
# Out:
# Index(['area', 'price'], dtype='object')

# %%
y =df['area']
x= df.drop(['area'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.25)

# %%
x_test
# Out:
#     price
# 1  565000
# 4  725000

# %%
y_test
# Out:
# 1    3000
# 4    4000
# Name: area, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
import pickle
classifier = KNeighborsClassifier(n_neighbors = 3)
classifier.fit(x_train, y_train)
pickle.dump(classifier,open('model.pkl','wb'))

# %%
pre=classifier.predict(x_test)

# %%
pre
# Out:
# array([2600, 2600])

# %%
print(y_test)
# Out:
# 1    3000
# 4    4000
# Name: area, dtype: int64

# %%
type(x_test)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.metrics import mean_squared_error
print('MSC is :',mean_squared_error(y_test,pre))
# Out:
# MSC is : 1060000.0

# %%
x=int(input('enter your area'))
d=pd.Series(x)
d1=pd.DataFrame(d)
pre=classifier.predict(d1)
print('your area prediction is :',pre)
# Out:
# enter your area15
# your area prediction is : [2600]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
