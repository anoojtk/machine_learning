# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('/content/drive/MyDrive/Dataset/tip-amount_(2).xlsx')
df
# Out:
#    Meal  Observed total bill(xi)  Observed tip bill(yi)
# 0     1                       34                      5
# 1     2                      108                     17
# 2     3                       64                     11
# 3     4                       88                      8
# 4     5                       99                     14

# %%
df.describe()
# Out:
#            Meal  Observed total bill(xi)  Observed tip bill(yi)
# count  5.000000                 5.000000               5.000000
# mean   3.000000                78.600000              11.000000
# std    1.581139                29.879759               4.743416
# min    1.000000                34.000000               5.000000
# 25%    2.000000                64.000000               8.000000
# 50%    3.000000                88.000000              11.000000
# 75%    4.000000                99.000000              14.000000
# max    5.000000               108.000000              17.000000

# %%
df.head()
# Out:
#    Meal  Observed total bill(xi)  Observed tip bill(yi)
# 0     1                       34                      5
# 1     2                      108                     17
# 2     3                       64                     11
# 3     4                       88                      8
# 4     5                       99                     14

# %%
df.columns
# Out:
# Index(['Meal', 'Observed total bill(xi)', 'Observed tip bill(yi)'], dtype='object')

# %%
y=df['Observed tip bill(yi)']
x=df.drop(['Observed tip bill(yi)','Meal'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.25)

# %%
x_test
# Out:
#    Observed total bill(xi)
# 1                      108
# 4                       99

# %%
y_test
# Out:
# 1    17
# 4    14
# Name: Observed tip bill(yi), dtype: int64

# %%
from sklearn.svm import SVC
SVC=SVC(kernel='linear')
SVC.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
pre=SVC.predict(x_test)

# %%
pre
# Out:
# array([8, 8])

# %%
print(y_test)
# Out:
# 1    17
# 4    14
# Name: Observed tip bill(yi), dtype: int64

# %%
type(x_test)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.metrics import mean_squared_error
print('MSC is :',mean_squared_error(y_test,pre))
# Out:
# MSC is : 58.5

# %%
x=int(input('enter a your total bill'))
a=pd.Series(x)
b=pd.DataFrame(a)
pre=SVC.predict(b)
pre
print(pre)
# Out:
# enter a your total bill555
# [8]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
type(a)
type(df)
# Out:
# pandas.core.frame.DataFrame
